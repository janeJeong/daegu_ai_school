# %% [markdown]
# # Face API Sample

# %%
import requests
from io import BytesIO
from PIL import Image, ImageDraw, ImageFont

# %%
subscription_key = 'af30cb4ec2a44010a054185e92b1a7bd'

# %%
face_api_url = 'https://daegufaceapi.cognitiveservices.azure.com/face/v1.0/detect'

# %%
image_url = 'https://mblogthumb-phinf.pstatic.net/MjAxOTAzMjRfMTQx/MDAxNTUzMzU1OTQzNTI3.-OgnroYRgf6jziVJErBfIThL2J4UiAeLLBUpSobQuW8g.H9Sjcdo9eflz3pjx76mgINY5pg9TGMX-i8JtNH28qZkg.JPEG.ptj0969/D2T0CJcU8AA9Lq5.jpg?type=w2'

# %%
img = Image.open(BytesIO(requests.get(image_url).content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=743x418 at 0x27340C47D90>

# %%
headers = {'Ocp-Apim-Subscription-Key' : subscription_key}

# %%
params = {
    'returnFaceID' : 'true',
    'returnFaceLandmarks' : 'false',
    'returnFaceAttributes' : 'age, gender, emotion'  # attribute - 속성, 가지고 있는 값
}

# %%
data = {'url' : image_url}

# %%
response = requests.post(face_api_url, params = params, headers = headers, json = data)

# %%
faces = response.json()

# %%
faces
# Out:
# [{'faceId': '1d2f3786-7463-489b-a2d3-be55473b9606',
#   'faceRectangle': {'top': 87, 'left': 238, 'width': 79, 'height': 79},
#   'faceAttributes': {'gender': 'male',
#    'age': 40.0,
#    'emotion': {'anger': 0.011,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.984,
#     'sadness': 0.0,
#     'surprise': 0.004}}},
#  {'faceId': '457dd337-5800-4bab-8921-b1d823a55821',
#   'faceRectangle': {'top': 182, 'left': 333, 'width': 61, 'height': 61},
#   'faceAttributes': {'gender': 'male',
#    'age': 32.0,
#    'emotion': {'anger': 0.255,
#     'contempt': 0.01,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.732,
#     'sadness': 0.002,
#     'surprise': 0.0}}},
#  {'faceId': 'e83fc553-b97c-42a6-9563-c98ac41f955b',
#   'faceRectangle': {'top': 98, 'left': 435, 'width': 60, 'height': 60},
#   'faceAttributes': {'gender': 'male',
#    'age': 37.0,
#    'emotion': {'anger': 0.066,
#     'contempt': 0.001,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.933,
#     'sadness': 0.0,
#     'surprise': 0.0}}},
#  {'faceId': '0fc816e9-f4fe-4898-8549-23a1e297058e',
#   'faceRectangle': {'top': 296, 'left': 369, 'width': 47, 'height': 47},
#   'faceAttributes': {'gender': 'female',
#    'age': 30.0,
#    'emotion': {'anger': 0.63,
#     'contempt': 0.002,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.364,
#     'sadness': 0.003,
#     'surprise': 0.001}}},
#  {'faceId': 'a04cdbc9-c1ee-49a0-985a-d9bef7dee8e2',
#   'faceRectangle': {'top': 250, 'left': 210, 'width': 36, 'height': 36},
#   'faceAttributes': {'gender': 'male',
#    'age': 41.0,
#    'emotion': {'anger': 0.054,
#     'contempt': 0.01,
#     'disgust': 0.001,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.777,
#     'sadness': 0.158,
#     'surprise': 0.0}}}]

# %% [markdown]
# ## 얼굴 이정표
# [얼굴이정표](https://docs.microsoft.com/ko-kr/azure/cognitive-services/face/concepts/face-detection)
# ![얼굴이정표](https://docs.microsoft.com/ko-kr/azure/cognitive-services/face/images/landmarks.1.jpg)

# %%
def CreateImage(faces) :
    
    for face in faces :
        
        # 사각형을 출력하기 위한 부분
        rect = face['faceRectangle']
        top = rect['top']
        left = rect['left']
        bottom = rect['height'] + top
        right = rect['width'] + left
        
        draw.rectangle(((left, top), (right, bottom)), outline = 'red')
        
        # 글씨를 쓰기 위한 부분
        
        fontX = left # -> left라는 값 내에 x가 이미 들어가 있음
        fontY = top - 30 
        
        face_info = face['faceAttributes']
        gender = face_info['gender']
        age = face_info['age']
        result = 'Gender: {0} \nAge: {1}'.format(gender, age)
        
        draw.text((fontX, fontY), result, fill = 'red')

# %%
draw = ImageDraw.Draw(img)

# %%
CreateImage(faces)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=743x418 at 0x27340C47D90>
